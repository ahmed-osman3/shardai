# %% [markdown]
# # 03 — Kalman filter gap-fill
#
# Runs `BallDetector` on a 30-second segment, then applies `BallTracker` to the detections. Plots the ball trajectory colour-coded by source (detected / interpolated / lost) and reports how much of the clip is covered with Kalman interpolation enabled.

# %% [markdown]
# ## Setup & imports

# %%
# TODO: implement — see doc/IMPLEMENTATION_PLAN.md §15

# %% [markdown]
# ## Run BallDetector on a 30-second segment

# %%
# TODO: iterate frames 0–1800 (30s @ 60fps), collect list[list[Detection]]

# %% [markdown]
# ## Run BallTracker on detection output

# %%
# TODO: feed detections into BallTracker.update(), collect list[TrackedBall | None]

# %% [markdown]
# ## Trajectory plot — x vs frame_idx, colour-coded by source

# %%
# TODO: scatter plot
#   green dots = detected
#   yellow dots = interpolated
#   red dots = lost (if any)

# %% [markdown]
# ## Coverage statistics

# %%
# TODO: print % detected, % interpolated, % lost

# %% [markdown]
# ## Example interpolated segments overlaid on frames

# %%
# TODO: pick 5 interpolated segments, show annotated frames with trajectory overlay

# %% [markdown]
# ## Conclusion
#
# TODO: fill in after running — Kalman gap-fill increases coverage from X% to Y%.
