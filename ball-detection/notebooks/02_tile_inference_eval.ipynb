# %% [markdown]
# # 02 — Tiled inference vs whole-frame inference
#
# Compares detection rate and inference speed for whole-frame vs tiled YOLO inference on the same 100 frames. Shows where tiling helps (far-end ball detection) and what it costs (time).

# %% [markdown]
# ## Setup & imports

# %%
# TODO: implement — see doc/IMPLEMENTATION_PLAN.md §14

# %% [markdown]
# ## Run whole-frame inference on 100 frames

# %%
# TODO: Config with tile_size=None (or tile_size > frame dimension)
# time it with time.perf_counter

# %% [markdown]
# ## Run tiled inference on same 100 frames

# %%
# TODO: Config with tile_size=640, tile_overlap=128

# %% [markdown]
# ## Detection rate comparison (bar chart)

# %%
# TODO: matplotlib bar chart — whole vs tiled detection rate

# %% [markdown]
# ## Inference time comparison (bar chart)

# %%
# TODO: bar chart — ms/frame for whole vs tiled

# %% [markdown]
# ## Side-by-side annotated frames (far-end example)

# %%
# TODO: pick a far-end frame, show whole vs tiled side by side

# %% [markdown]
# ## Conclusion
#
# TODO: fill in after running — tiling improves detection rate by X% at a cost of Yms/frame.
