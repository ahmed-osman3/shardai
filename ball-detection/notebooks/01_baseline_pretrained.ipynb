# %% [markdown]
# # 01 — Baseline: pretrained YOLO11 on a match clip
#
# Loads `yolo11m.pt` (COCO weights), runs whole-frame inference on a sample clip using class 32 (sports ball), and reports the detection rate. This sets the **floor expectation** before fine-tuning or tiling.

# %% [markdown]
# ## Setup & imports

# %%
# TODO: implement — see doc/IMPLEMENTATION_PLAN.md §13
# import sys; sys.path.insert(0, '..')
# from config import Config
# from src.detection import BallDetector

# %% [markdown]
# ## Load model & config

# %%
# TODO: Config(tile_size=None) — whole-frame mode
# detector = BallDetector(config)

# %% [markdown]
# ## Run on first 500 frames of a sample clip

# %%
# TODO: iterate clip, collect detections, compute detection_rate = detected_frames / total_frames

# %% [markdown]
# ## Detection rate + annotated sample frames

# %%
# TODO: print detection_rate
# TODO: show 10 annotated frames using supervision BoxAnnotator

# %% [markdown]
# ## Conclusion
#
# TODO: fill in after running — baseline detection rate = X%. Far-end detection rate = Y%.
